# %%
import numpy as np
import matplotlib.pyplot as plt

import matplotlib as mpl

# %%
gradient = np.linspace(0, 1, 256)
gradient = np.vstack((gradient, gradient))

def plot_color_gradients(category, cmap_list):
    # Create figure and adjust figure height to number of colormaps
    nrows = len(cmap_list)
    figh = 0.35 + 0.15 + (nrows + (nrows - 1) * 0.1) * 0.22
    fig, axs = plt.subplots(nrows=nrows + 1, figsize=(6.4, figh))
    fig.subplots_adjust(top=1 - 0.35 / figh, bottom=0.15 / figh,
                        left=0.2, right=0.99)
    axs[0].set_title(f'{category} colormaps', fontsize=14)

    for ax, cmap in zip(axs, cmap_list):
        ax.imshow(gradient, aspect='auto', cmap=cmap)
        ax.text(-0.01, 0.5, cmap, va='center', ha='right', fontsize=10,
                transform=ax.transAxes)

    # Turn off *all* ticks & spines, not just the ones with colormaps.
    for ax in axs:
        ax.set_axis_off()

    # Save colormap list for later.
    # cmaps[category] = cmap_list

# %%
# mycmap = mpl.colormaps['viridis']
# print(len(mycmap.colors))

# -1000~1000
# 2000+1=2001
# mycmap1 = mpl.colormaps['hsv'].resampled(8)
# mycmap1 = mpl.colormaps['hsv'].resampled(8)
# print(len(mycmap1.colors))

# copper = mpl.colormaps['turbo'].resampled(8)
# copper = mpl.colormaps['turbo']
copper = mpl.colormaps['rainbow']
copper1 = mpl.colormaps['rainbow'].resampled(2001)

# print('copper colors', len(copper.colors))

print('copper(np.linspace(0, 1, 8))', copper(np.linspace(0, 1, 8)))
print('copper1(np.linspace(0, 1, 8))', copper1(np.linspace(0, 1, 8)))

plot_color_gradients('def', [copper, copper1])
# Out:
# copper(np.linspace(0, 1, 8)) [[5.00000000e-01 0.00000000e+00 1.00000000e+00 1.00000000e+00]
#  [2.17647059e-01 4.29120609e-01 9.75511968e-01 1.00000000e+00]
#  [7.25490196e-02 7.82927610e-01 9.00586702e-01 1.00000000e+00]
#  [3.54901961e-01 9.74138602e-01 7.82927610e-01 1.00000000e+00]
#  [6.45098039e-01 9.74138602e-01 6.22112817e-01 1.00000000e+00]
#  [9.27450980e-01 7.82927610e-01 4.34676422e-01 1.00000000e+00]
#  [1.00000000e+00 4.29120609e-01 2.19946358e-01 1.00000000e+00]
#  [1.00000000e+00 1.22464680e-16 6.12323400e-17 1.00000000e+00]]
# copper1(np.linspace(0, 1, 8)) [[5.00000000e-01 0.00000000e+00 1.00000000e+00 1.00000000e+00]
#  [2.15000000e-01 4.32872582e-01 9.75052593e-01 1.00000000e+00]
#  [7.10000000e-02 7.81411573e-01 9.01114862e-01 1.00000000e+00]
#  [3.57000000e-01 9.74877954e-01 7.81901433e-01 1.00000000e+00]
#  [6.43000000e-01 9.74877954e-01 6.23402077e-01 1.00000000e+00]
#  [9.29000000e-01 7.81411573e-01 4.33580449e-01 1.00000000e+00]
# ...

# %%
copper = mpl.colormaps['rainbow']
print(type(copper))

colormap_list = list(mpl.colormaps)

for colormap in colormap_list:
    print(f'{colormap}: {type(copper)}')
# Out:
# <class 'matplotlib.colors.LinearSegmentedColormap'>
# magma: <class 'matplotlib.colors.LinearSegmentedColormap'>
# inferno: <class 'matplotlib.colors.LinearSegmentedColormap'>
# plasma: <class 'matplotlib.colors.LinearSegmentedColormap'>
# viridis: <class 'matplotlib.colors.LinearSegmentedColormap'>
# cividis: <class 'matplotlib.colors.LinearSegmentedColormap'>
# twilight: <class 'matplotlib.colors.LinearSegmentedColormap'>
# twilight_shifted: <class 'matplotlib.colors.LinearSegmentedColormap'>
# turbo: <class 'matplotlib.colors.LinearSegmentedColormap'>
# Blues: <class 'matplotlib.colors.LinearSegmentedColormap'>
# BrBG: <class 'matplotlib.colors.LinearSegmentedColormap'>
# BuGn: <class 'matplotlib.colors.LinearSegmentedColormap'>
# BuPu: <class 'matplotlib.colors.LinearSegmentedColormap'>
# CMRmap: <class 'matplotlib.colors.LinearSegmentedColormap'>
# GnBu: <class 'matplotlib.colors.LinearSegmentedColormap'>
# Greens: <class 'matplotlib.colors.LinearSegmentedColormap'>
# ...
